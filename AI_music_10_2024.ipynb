# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewCieslik/JupiterTensorFlowKeras/blob/master/AI_music_10_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Udio wyróżnia się jako niezwykły generator muzyki AI, który wykorzystuje potencjał sztucznej inteligencji do tworzenia niestandardowych utworów muzycznych. Często określane jako „ChatGPT dla muzyki”, Udio upraszcza proces tworzenia muzyki, umożliwiając użytkownikom opisywanie pożądanej muzyki pod względem gatunku, instrumentów i innych szczegółów. Platforma tłumaczy te dane tekstowe na kompletne, wysokiej jakości kompozycje muzyczne, prezentując zarówno zaawansowaną technologię, jak i przyjazny dla użytkownika design.
#
#
# ---
#
#
# Rozwój Udio przypisuje się zespołowi byłych badaczy Google DeepMind, w tym Davidowi Dingowi, Conorowi Durkanowi, Charliemu Nashowi, Yaroslavowi Ganinowi i Andrew Sanchezowi. Wykorzystując swoją głęboką wiedzę w zakresie sztucznej inteligencji, dostosowali Udio do demokratyzacji produkcji muzycznej, udostępniając ją użytkownikom bez przeszkolenia muzycznego. Ta innowacja nie tylko podkreśla możliwości sztucznej inteligencji w branżach kreatywnych, ale także zmienia sposób konceptualizacji i tworzenia muzyki.
#
#
# ---
#
#
# Generacja muzyki AI: Udio konwertuje opisy tekstowe na pełne utwory muzyczne za pomocą sztucznej inteligencji.
# Przyjazny użytkownikowi: nazwany „ChatGPT dla muzyki” jest dostępny dla osób niebędących muzykami.
# Muzyka wysokiej jakości: Tworzy wyrafinowane kompozycje wysokiej jakości.
# Zespół ekspertów: Stworzony przez byłych badaczy Google DeepMind.
# Demokratyzuje muzykę: sprawia, że ​​tworzenie muzyki jest dostępne dla wszystkich.
#
# źródło: https://www.unite.ai/pl/best-ai-music-generators/

# %% [markdown]
# "stworz cos w stylu chaconne na skrzypce"

# %%
from IPython.display import Audio

# Path to your MP3 file
audio_path = '/content/Eternal Variations.mp3'

# Display the audio player
Audio(audio_path, autoplay=False)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
